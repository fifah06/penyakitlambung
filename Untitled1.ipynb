# %% [markdown]
# <a href="https://colab.research.google.com/github/fifah06/penyakitlambung/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installing the kaggle library
# !pip install kaggle

# %%
# configuring the path of kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# kaggle api
# !kaggle competitions download -c dogs-vs-cats-redux-kernels-edition
# Out:
# dogs-vs-cats-redux-kernels-edition.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
#  dogs-vs-cats-redux-kernels-edition.zip   kaggle.json   sample_submission.csv   train
# 'image resized'				  sample_data   test.zip	        train.zip

# %%
# extracting the compressed dataset
from zipfile import ZipFile

dataset = '/content/dogs-vs-cats-redux-kernels-edition.zip'

with ZipFile(dataset, 'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
# extracting the compressed dataset
from zipfile import ZipFile

dataset = '/content/train.zip'

with ZipFile(dataset, 'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
import os
# counting the number of files in train folder
path, dirs, files = next(os.walk('/content/train'))
file_count= len(files)
print('Number of images: ', file_count)
# Out:
# Number of images:  25000

# %%
import os

file_names = os.listdir('/content/train/')
print(file_names)
# Out:
# ['cat.11582.jpg', 'cat.9790.jpg', 'dog.7579.jpg', 'dog.11635.jpg', 'cat.11028.jpg', 'cat.8487.jpg', 'dog.12263.jpg', 'dog.722.jpg', 'cat.2554.jpg', 'cat.8631.jpg', 'dog.11377.jpg', 'dog.9084.jpg', 'dog.4799.jpg', 'dog.3140.jpg', 'dog.9838.jpg', 'cat.3797.jpg', 'dog.12110.jpg', 'dog.5513.jpg', 'dog.1334.jpg', 'cat.6416.jpg', 'dog.11241.jpg', 'cat.11377.jpg', 'dog.1077.jpg', 'cat.4833.jpg', 'dog.9139.jpg', 'cat.3979.jpg', 'cat.1135.jpg', 'dog.5014.jpg', 'dog.11673.jpg', 'cat.10790.jpg', 'cat.899.jpg', 'dog.3864.jpg', 'cat.11691.jpg', 'cat.4719.jpg', 'dog.7818.jpg', 'cat.2076.jpg', 'dog.8163.jpg', 'cat.3306.jpg', 'cat.8454.jpg', 'cat.11592.jpg', 'cat.4673.jpg', 'dog.4477.jpg', 'cat.5693.jpg', 'cat.1723.jpg', 'dog.7367.jpg', 'cat.4224.jpg', 'cat.12196.jpg', 'dog.3139.jpg', 'dog.5220.jpg', 'dog.4365.jpg', 'dog.3241.jpg', 'dog.11650.jpg', 'cat.471.jpg', 'dog.5604.jpg', 'dog.7101.jpg', 'dog.2695.jpg', 'dog.3716.jpg', 'dog.190.jpg', 'dog.2004.jpg', 'cat.10357.jpg', 'cat.8934.jpg', 'dog.9613.
# ...

# %%
import numpy as np
from PIL import Image  # Impor 'Image' dari modul 'PIL'
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
from google.colab.patches import cv2_imshow

# %%
# gambar anjing
img = mpimg.imread('/content/train/dog.11635.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
# gambar kucing
img = mpimg.imread('/content/train/cat.11582.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
files_names = os.listdir('/content/train/')

for i in range(5):

  name = file_names[i]
  print(name[0:3])
# Out:
# cat
# cat
# dog
# dog
# cat

# %%
file_names = os.listdir('/content/train/')

dog_count = 0
cat_count = 0

for img_file in file_names:

  name = img_file[0:3]

  if name == 'dog':
    dog_count += 1

  else:
    cat_count +=1

print('Number of dog images =', dog_count)
print('Number of cat images =', cat_count)
# Out:
# Number of dog images = 12500
# Number of cat images = 12500

# %%
# pembuatan folder untuk gambar yang telah di resize
os.mkdir('/content/image resized')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-19-87aa65e91192> in <cell line: 2>()
#       1 # pembuatan folder untuk gambar yang telah di resize
# ----> 2 os.mkdir('/content/image resized')
#
# FileExistsError: [Errno 17] File exists: '/content/image resized'

# %%
original_folder = '/content/train/'
resized_folder = '/content/image resized/'

for i in range(2000):

  filename = os.listdir(original_folder)[i]
  img_path = original_folder+filename

  img = Image.open(img_path)
  img = img.resize((224, 224))
  img = img.convert('RGB')

  newImgPath = resized_folder+filename
  img.save(newImgPath)

# %%
# tampilkan gambar anjing setelah resize
img = mpimg.imread('/content/image resized/dog.11635.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
# tampilkan gambar kucing setelah resize
img = mpimg.imread('/content/image resized/cat.11582.jpg')
imgplt = plt.imshow(img)
plt.show()

# %% [markdown]
# Buat label Pada Resize Gambar Kucing dan Anjing
#
# Kucing-->0
# Anjing-->1

# %%
# pembuatan label
import os
filename = os.listdir('/content/image resized/')

labels = []

for i in range(2000):

  file_name = filename[i]
  label = file_name[0:3]

  if label == 'dog':
    labels.append(1)
  else:
    labels.append(0)

# %%
print(filename[0:5])
print(len(filename))
# Out:
# ['cat.11582.jpg', 'cat.9790.jpg', 'dog.7579.jpg', 'dog.11635.jpg', 'cat.11028.jpg']
# 2000

# %%
print(labels[0:5])
print(len(labels))
# Out:
# [0, 0, 1, 1, 0]
# 2000

# %%
# perhitungan gambar kucing dan anjing dari 2000 gambar
values, count = np.unique(labels, return_counts=True)
print(values)
print(count)
# Out:
# [0 1]
# [1012  988]

# %% [markdown]
# convert semua gambar resize ke numpy arrays

# %%
import cv2
import glob

# %%
image_directory = '/content/image resized/'
image_extension = ['png', 'jpg']

files = []

[files.extend(glob.glob(image_directory + '*.' +e)) for e in image_extension]

dog_cat_images = np.asarray([cv2.imread(file) for file in files])

# %%
print(dog_cat_images)
# Out:
# [[[[ 87  90  88]
#    [ 87  90  88]
#    [ 88  91  89]
#    ...
#    [243 243 243]
#    [242 242 242]
#    [241 241 241]]
#
#   [[ 88  91  89]
#    [ 88  91  89]
#    [ 89  92  90]
#    ...
#    [244 244 244]
#    [243 243 243]
#    [243 243 243]]
#
#   [[ 89  92  90]
#    [ 90  93  91]
#    [ 91  94  92]
#    ...
#    [246 246 246]
#    [245 245 245]
#    [245 245 245]]
#
#   ...
#
#   [[ 85  90  89]
#    [ 80  85  84]
#    [ 53  58  57]
#    ...
#    [214 213 209]
#    [214 213 209]
#    [207 206 202]]
#
#   [[ 76  81  80]
#    [ 76  81  80]
#    [ 51  56  55]
#    ...
#    [211 210 206]
#    [210 209 205]
#    [203 202 198]]
#
#   [[ 75  80  79]
#    [ 78  83  82]
#    [ 53  58  57]
#    ...
#    [208 207 203]
#    [207 206 202]
#    [200 199 195]]]
#
#
#  [[[ 31  41  51]
#    [132 141 150]
#    [ 97 102 105]
#    ...
#    [ 95  87  87]
#    [230 218 218]
#    [135 121 122]]
#
#   [[ 36  46  56]
#    [134 143 152]
#    [103 108 111]
#    ...
#    [ 97  89  89]
#    [226 214 214]
# ...

# %%
type(dog_cat_images)
# Out:
# numpy.ndarray

# %%
print(dog_cat_images.shape)
# Out:
# (2000, 224, 224, 3)

# %%
X = dog_cat_images
Y = np.asarray(labels)

# %% [markdown]
# **Train Test Split**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (2000, 224, 224, 3) (1600, 224, 224, 3) (400, 224, 224, 3)

# %% [markdown]
# 1600--> training images
# 400--> test image

# %%
# scalling the data
X_train_scaled = X_train/255

X_test_scaled = X_test/255

# %%
print(X_train_scaled)
# Out:
# [[[[0.43529412 0.58823529 0.7372549 ]
#    [0.43529412 0.58823529 0.7372549 ]
#    [0.43137255 0.58431373 0.73333333]
#    ...
#    [0.40784314 0.55686275 0.55686275]
#    [0.40784314 0.55686275 0.55686275]
#    [0.40784314 0.55686275 0.55686275]]
#
#   [[0.42745098 0.58039216 0.72941176]
#    [0.42352941 0.57647059 0.7254902 ]
#    [0.42352941 0.57647059 0.7254902 ]
#    ...
#    [0.40784314 0.55686275 0.55686275]
#    [0.40784314 0.55686275 0.55686275]
#    [0.40784314 0.55686275 0.55686275]]
#
#   [[0.41568627 0.56862745 0.71764706]
#    [0.41176471 0.56470588 0.71372549]
#    [0.40784314 0.56078431 0.70980392]
#    ...
#    [0.40784314 0.55686275 0.55686275]
#    [0.40784314 0.55686275 0.55686275]
#    [0.40784314 0.55686275 0.55686275]]
#
#   ...
#
#   [[0.33333333 0.5372549  0.65490196]
#    [0.33333333 0.5372549  0.65490196]
#    [0.3372549  0.54117647 0.65882353]
#    ...
#    [0.45490196 0.61960784 0.73333333]
#    [0.45490196 0.61960784 0.73333333]
# ...

# %% [markdown]
# Pembuatan Neural Network

# %%
import tensorflow as tf
import tensorflow_hub as hub

# %%
mobilenet_model = 'https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4'

pretrained_model = hub.KerasLayer(mobilenet_model, input_shape=(224,224,3), trainable=False)

# %%
num_of_classes = 2

model = tf.keras.Sequential([

    pretrained_model,
    tf.keras.layers.Dense(num_of_classes)

])

model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-82d1e9e5029b> in <cell line: 3>()
#       1 num_of_classes = 2
#       2
# ----> 3 model = tf.keras.Sequential([
#       4
#       5     pretrained_model,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/sequential.py in __init__(self, layers, trainable, name)
#      73         if layers:
#      74             for layer in layers:
# ---> 75                 self.add(layer, rebuild=False)
#      76             self._maybe_rebuild()
#      77
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/sequential.py in add(self, layer, rebuild)
#      95                 layer = origin_layer
#      96         if not isinstance(layer, Layer):
# ---> 97             raise ValueError(
#      98                 "Only instances of `keras.Layer` can be "
# ...
